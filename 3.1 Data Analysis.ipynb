# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify the distribution of data in the dataset.
#
# -   Identify outliers in the dataset.
#
# -   Remove outliers from the dataset.
#
# -   Identify correlation between features in the dataset.

# %% [markdown]
# * * *

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
import numpy as np

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here
data = df['ConvertedComp']
sns.displot(data, kde=True, bins=60)

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here
sns.displot(data, kde=False, color= 'red', bins=60)

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
print('Median =',df['ConvertedComp'].median())
# Out:
# Median = 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
df['Gender'].value_counts()
# Out:
# Gender
# Man                                                            10480
# Woman                                                            731
# Non-binary, genderqueer, or gender non-conforming                 63
# Man;Non-binary, genderqueer, or gender non-conforming             26
# Woman;Non-binary, genderqueer, or gender non-conforming           14
# Woman;Man                                                          9
# Woman;Man;Non-binary, genderqueer, or gender non-conforming        2
# Name: count, dtype: int64

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
Wm_data= df.loc[df['Gender'] == 'Woman', 'ConvertedComp']

print('median =',Wm_data.median())
# Out:
# median = 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
data_age = df['Age']


dAge=pd.DataFrame(data_age.quantile([0, 0.25, 0.5, 0.75, 1]))

dAge['Data Type'] = ['Min', 'Q1','Median', 'Q3', 'Max' ]
dAge.set_index('Data Type')
# Out:
#             Age
# Data Type
# Min        16.0
# Q1         25.0
# Median     29.0
# Q3         35.0
# Max        99.0

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here
sns.displot(data_age, kde=False, color= 'red', bins=15)

# %%
sns.boxplot(data= df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here


sns.boxplot(data= df['ConvertedComp'])
# Out:
# <Axes: ylabel='ConvertedComp'>

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
print('IQR = ',df['ConvertedComp'].quantile(0.75) - df['ConvertedComp'].quantile(0.25) )
# Out:
# IQR =  73132.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here
Q1 = df['ConvertedComp'].quantile(0.25)
Q3 = df['ConvertedComp'].quantile(0.75)
IQR = Q3 - Q1

lower  =  Q1 - 1.5*IQR
upper =   Q3 + 1.5*IQR

print(f'upper bound = {upper} \nlower bound = {lower}')
# Out:
# upper bound = 209698.0
# lower bound = -82830.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here


upper_array = np.where(df['ConvertedComp'] >= upper)[0].tolist()
lower_array = np.where(df['ConvertedComp'] <= lower)[0].tolist()

print('outlier upper  = ', upper_array)
print('outlier lower = ', lower_array)
# Out:
# outlier upper  =  [3, 13, 45, 46, 60, 70, 71, 76, 104, 111, 119, 120, 123, 130, 131, 203, 210, 237, 249, 264, 306, 308, 321, 334, 347, 348, 351, 358, 367, 369, 370, 374, 390, 405, 408, 412, 427, 431, 432, 442, 457, 467, 468, 477, 481, 505, 513, 541, 582, 615, 617, 631, 647, 655, 656, 658, 660, 662, 682, 686, 728, 733, 737, 740, 744, 747, 751, 757, 801, 817, 850, 859, 867, 874, 908, 988, 989, 1011, 1019, 1037, 1046, 1058, 1068, 1082, 1084, 1095, 1110, 1114, 1135, 1136, 1143, 1170, 1218, 1222, 1225, 1236, 1255, 1258, 1280, 1283, 1306, 1308, 1323, 1334, 1352, 1354, 1361, 1362, 1371, 1397, 1417, 1436, 1438, 1451, 1462, 1468, 1488, 1501, 1515, 1520, 1525, 1535, 1545, 1548, 1576, 1600, 1623, 1625, 1630, 1674, 1680, 1685, 1703, 1719, 1722, 1739, 1757, 1763, 1777, 1778, 1786, 1790, 1791, 1818, 1819, 1824, 1843, 1847, 1851, 1881, 1890, 1892, 1894, 1901, 1923, 1986, 2001, 2043, 2045, 2049, 2084, 2091, 2100, 2107, 2147, 2160, 2161, 2164, 2166, 2179, 2180, 2205, 2223, 2224, 2239, 2251, 2254, 226
# ...

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here


df.drop(index=upper_array, inplace= True)
df.shape
# Out:
# (10519, 85)

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here
df.corr(numeric_only= True)
# Out:
#                Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs  \
# Respondent       1.000000  -0.019364       0.010878    -0.015275    0.002980
# CompTotal       -0.019364   1.000000      -0.063561     0.004975    0.017536
# ConvertedComp    0.010878  -0.063561       1.000000     0.034351   -0.088934
# WorkWeekHrs     -0.015275   0.004975       0.034351     1.000000    0.031963
# CodeRevHrs       0.002980   0.017536      -0.088934     0.031963    1.000000
# Age              0.003950   0.006371       0.401821     0.037452   -0.017961
#
#                     Age
# Respondent     0.003950
# CompTotal      0.006371
# ConvertedComp  0.401821
# WorkWeekHrs    0.037452
# CodeRevHrs    -0.017961
# Age            1.000000

# %%
df['ConvertedComp'].mean()
# Out:
# 59883.20838915799

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
